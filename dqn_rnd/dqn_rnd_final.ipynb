# %% [markdown]
# # 3.4 DQN with non-domain sepcific reward

# %% [markdown]
# ### Load libraries

# %%
""""0. initialize libraries and setup tools"""

# !load_ext jupyternotify

import numpy as np
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import models
import json
# Out:
# zsh:1: command not found: load_ext

# %% [markdown]
# ### Set up the environment

# %%
env = gym.make('MountainCar-v0')

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()  # checks if one is running IPhyton environment like jupyter notebook
if is_ipython:
    from IPython import display

plt.ion()  # interactive mode on, allows automatic plots when data is updated (whithout calling plt.show every time)

# if GPU is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Functions for plotting

# %%
""" 1.1. Helper functions """
    
def plot_durations(episode_durations, run_id):
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Duration per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.scatter(list(range(len(episode_durations))), durations_t.numpy(), color='grey')
    
    moving_avg = []
    for i in range(len(episode_durations)):
        if i < 100:
            moving_avg.append(durations_t[:i+1].mean().item())  
        else:
            moving_avg.append(durations_t[i-99:i+1].mean().item()) 
    
    plt.plot(range(len(episode_durations)), moving_avg, color='orange', label='100-Moving Average')
    plt.legend()
    plt.savefig(f"DQN_Duration_Hyperparameters_{run_id}.png", dpi=300)
    plt.close()
    
def plot_curve(data, title, xlabel, ylabel, run_id):
    plt.plot(data)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.savefig(f"DQN_{title}_H{run_id}.png", dpi=300)
    plt.close()

def plot_cumul_reward(data, xlabel, ylabel, run_id):
    plt.figure(1)
    data_t = torch.tensor(data, dtype=torch.float)
    plt.title('Cumulative Reward Per Episode')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.scatter(list(range(len(data))), data_t.numpy(), color = 'grey', label='Cumulative Reward Per Episode') 
    if len(data_t) > 100:
        means = data_t[100:].unfold(0, 100, 1).mean(1).view(-1)
        plt.plot(range(100, len(data)-99), means.numpy(), color = 'orange', label='Moving Average (100 episodes)')
    plt.legend()
    plt.savefig(f"DQN_Cumul_Reward_{run_id}.png", dpi=300)
    plt.close()
    
def cumulative_sum(input_list):
    result = []
    running_total = 0
    for element in input_list:
        running_total += element
        result.append(running_total)
    return result

def plot_comp_cumul_reward(data, data_env, data_aux, run_id=1):
    data_t = torch.tensor(data, dtype=torch.float)
    plt.title('Composition of Averaged Cumulative Reward per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Cumulative Reward')
    c_e_r_p_e_t = torch.tensor(data_env, dtype=torch.float)
    c_a_r_p_e_t = torch.tensor(data_aux, dtype=torch.float)
    if len(c_e_r_p_e_t) > 100:  # Check if data has more than 100 episodes
            # Calculate and plot the average line starting from episode 100
            means = data_t[100:].unfold(0, 100, 1).mean(1).view(-1)
            plt.plot(range(100, len(data)-99), means.numpy(), color='cyan', label='Moving Average Reward Per Episode')
            plt.scatter(torch.arange(len(data_t)), data_t, s = 2, color='blue', label='Cumulative Reward Per Episode')
            # Calculate and plot moving average starting from episode 100
            means = c_e_r_p_e_t[100:].unfold(0, 100, 1).mean(1).view(-1)
            plt.plot(range(100, len(data_env)-99), means.numpy(), color='yellow', label='Moving Average Environment Reward Per Episode')
            plt.scatter(torch.arange(len(data_t)), c_e_r_p_e_t, s=2, color='goldenrod', label='Cumulative Environment Reward Per Episode')
            # Plot the average line starting from episode 100
            means = c_a_r_p_e_t[100:].unfold(0, 100, 1).mean(1).view(-1)
            plt.plot(range(100, len(data_aux)-99), means.numpy(), color='springgreen', label='Moving Average Intrinsic Reward Per Episode')
            plt.scatter(torch.arange(len(data_t)), c_a_r_p_e_t, s=2, color='forestgreen',label='Cumulative Intrinsic Reward Per Episode')
    plt.legend()
    plt.savefig(f"DQN_Comp_Cumul_Reward_{run_id}.png", dpi=300)
    plt.close()

def plot_evaluation(episode_durations, run_id):
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Duration per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.scatter(list(range(len(episode_durations))), durations_t.numpy(), color='grey')
    
    moving_avg = []
    for i in range(len(episode_durations)):
        if i < 100:
            moving_avg.append(durations_t[:i+1].mean().item())  
        else:
            moving_avg.append(durations_t[i-99:i+1].mean().item()) 
    
    plt.plot(range(len(episode_durations)), moving_avg, color='orange', label='100-Moving Average')
    plt.legend()
    plt.savefig(f"DQN_Evaluation_Hyperparameters_{run_id}.png", dpi=300)
    plt.close()

# %% [markdown]
# ### Classes for DQN and RND + buffer
# We have also set up a RunningStats class for more clear processing of the means and standard deviations for both rewards and states.

# %%
""""1.2. Define ReplayBuffer and deep q network"""

Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward', 'reward_int'))

class ReplayBuffer(object):

    def __init__(self, capacity):
        self.buffer = deque([], maxlen=capacity)

    def push(self, *args):
        self.buffer.append(Transition(*args)) #Save a transition

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

class DQN(nn.Module):

    def __init__(self, n_observations, n_actions, n_nodes_per_layer=64, n_layers=2):
        super(DQN, self).__init__()
        self.layers = nn.ModuleList([nn.Linear(n_observations, n_nodes_per_layer)])
        for _ in range(n_layers - 1):
            self.layers.append(nn.Linear(n_nodes_per_layer, n_nodes_per_layer))
        self.output_layer = nn.Linear(n_nodes_per_layer, n_actions)

    def forward(self, x):
        for layer in self.layers:
            x = F.relu(layer(x))
        return self.output_layer(x)
    
class RNDNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, n_hid):
        super(RNDNetwork, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, n_hid),
            nn.ReLU(),
            nn.Linear(n_hid, n_hid),
            nn.ReLU(),
            nn.Linear(n_hid, output_dim),
        )

    def forward(self, x):
        return self.network(x)
            
class RND:
    def __init__(self,in_dim,out_dim,n_hid):
        self.target = RNDNetwork(in_dim,out_dim,n_hid)
        self.predictor = RNDNetwork(in_dim,out_dim,n_hid)
        self.optimizer = torch.optim.Adam(self.predictor.parameters(),lr=0.0001)
        
    def get_reward(self, x):
        y_true = self.target(x).detach()  # Detaching to stop gradients
        y_pred = self.predictor(x)
        #reward = torch.pow(y_pred - y_true, 2).sum()
        reward = nn.MSELoss()(y_pred, y_true).to(device)
        return reward, y_pred

    def update(self, x):
        self.optimizer.zero_grad()
        r,__= self.get_reward(x)
        loss = r
        loss.backward()  # Compute gradients
        self.optimizer.step()
    

class RunningStats:
    def __init__(self, dimension=None, device='cpu'):
        self.n = 0
        self.mean = None
        self.M2 = 0
        self.dimension = dimension
        self.std = 1
        self.device = device

    def update(self, x):
        if torch.is_tensor(x) == False:
            x = torch.tensor(x, device=self.device)  # Convert to tensor if not already

        if self.mean is None:
            self.mean = torch.zeros_like(x, device=self.device)
            self.M2 = torch.zeros_like(x, device=self.device)

        self.n += 1
        delta = x - self.mean
        self.mean += delta / self.n
        delta2 = x - self.mean
        self.M2 += delta * delta2

    def variance(self):
        if self.n < 2:
            return torch.zeros_like(self.mean)
        return self.M2 / (self.n - 1)

    def std_dev(self):
        self.std = torch.sqrt(self.variance())
        return self.std

    @property
    def get_mean(self):
        return self.mean

    @property
    def get_std(self):
        return self.std

# %% [markdown]
# ### Agent class
# Includes the evaluation method for the comaprison part

# %%
"""" 2. Agent class """

class DQNAgent:
    def __init__(self, BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TAU, LR, n_actions, n_observations):
        self.BATCH_SIZE = BATCH_SIZE
        self.GAMMA = GAMMA
        self.EPS_START = EPS_START
        self.EPS_END = EPS_END
        self.EPS_DECAY = EPS_DECAY
        self.TAU = TAU
        self.LR = LR
        self.n_actions = n_actions
        self.n_observations = n_observations
        self.memory = ReplayBuffer(10000)
        self.policy_net = DQN(n_observations, n_actions).to(device)
        self.target_net = DQN(n_observations, n_actions).to(device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=LR)
        self.steps_done = 0
        self.episode_durations = []
        self.loss_per_episode = []
        self.cumulative_reward_per_episode = []
        self.cumulative_environment_reward_per_episode = []
        self.cumulative_intrinsic_reward_per_episode = []
        self.agent_performance = []
        self.testing_durations = []

        self.reward_factor = 2.5
        #self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        
        #self.predictor_net = RNDNetwork(n_observations, 1).to(device)
        #self.target_rnd_net = RNDNetwork(n_observations, 1).to(device)
        self.rnd = RND(n_observations,1,128)

        # Running statistics for normalization
        self.state_stats = RunningStats()
        self.reward_stats = RunningStats()


    def select_action(self, state):
        sample = random.random()
        eps_threshold = self.EPS_END + (self.EPS_START - self.EPS_END) * math.exp(-1. * self.steps_done / self.EPS_DECAY)
        self.steps_done += 1
        if sample > eps_threshold:
            with torch.no_grad():
                return self.policy_net(state).max(1)[1].view(1, 1)
        else:
            return torch.tensor([[random.randrange(self.n_actions)]], device=device, dtype=torch.long)

    def optimize_model(self):
        if len(self.memory) < self.BATCH_SIZE:
            return
        transitions = self.memory.sample(self.BATCH_SIZE)
        batch = Transition(*zip(*transitions))
        
        non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                                batch.next_state)), device=device, dtype=torch.bool)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        reward_int_batch = torch.cat([r[0].unsqueeze(0) for r in batch.reward_int if r is not None])
        #reward_int_batch_norm = self.normalise_reward(reward_int_batch).detach()
        
        state_action_values = self.policy_net(state_batch).gather(1, action_batch)
        
        next_state_values = torch.zeros(self.BATCH_SIZE, device=device)
        with torch.no_grad():
            next_state_values[non_final_mask] = self.target_net(non_final_next_states).max(1).values
        #for ri in reward_int_batch:
        #    self.reward_stats.update(ri.detach())
        #print("Total reward:", torch.sum(reward_batch + ((reward_int_batch.detach()-self.reward_stats.mean)/self.reward_stats.std).clamp(-5,5) * self.reward_factor))
        #print("Just intrinsic reward:", ((reward_int_batch.detach()-self.reward_stats.mean)/self.reward_stats.std).clamp(-5,5))
        expected_state_action_values = (next_state_values * self.GAMMA) + reward_batch + ((reward_int_batch.detach()-self.reward_stats.mean)/self.reward_stats.std).clamp(-5,5) * self.reward_factor
        expected_state_action_values = expected_state_action_values.float()

        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        
        self.optimizer.zero_grad()
        loss.backward()
        for param in self.policy_net.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
        
        #for state in state_batch:
        #    self.state_stats.update(state)
        state_batch_norm = (state_batch-self.state_stats.mean)/self.state_stats.std
        self.rnd.update(state_batch_norm)

        return loss.item()

    def update(self, num_episodes, M):
        preliminary_r_i = []
        for m in range(M):
                state, info = env.reset()
                state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
                action = self.select_action(state)
                observation, reward, terminated, truncated, _ = env.step(action.item())
                observation = torch.tensor(observation, dtype=torch.float32, device=device)
                self.state_stats.update(observation)
                state_norm = (observation-self.state_stats.mean)/self.state_stats.std
                reward_int = self.rnd.get_reward(state_norm)
                preliminary_r_i.append(reward_int[0])
        self.reward_stats.mean = torch.mean(torch.tensor(preliminary_r_i)).to(device)
        self.reward_stats.std = torch.std(torch.tensor(preliminary_r_i)).to(device)
        for episode in range(num_episodes):
            state, info = env.reset()
            state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            cumulative_reward_t = 0
            environment_reward_t = 0
            intrinsic_reward_t = 0
            running_loss = []
            for t in count():
                action = self.select_action(state)
                observation, reward, terminated, truncated, _ = env.step(action.item())
                environment_reward_t += reward
                reward = torch.tensor([reward], device=device)
                observation = torch.tensor(observation, dtype=torch.float32, device=device)

                state_norm = (observation-self.state_stats.mean)/self.state_stats.std
                reward_int = self.rnd.get_reward(state_norm)
                intrinsic_reward_t += ((reward_int[0] - self.reward_stats.mean)/self.reward_stats.std + 1e-8).clamp(-5,5)
                cumulative_reward_t += environment_reward_t + intrinsic_reward_t.detach()
                self.state_stats.update(observation)
                self.reward_stats.update(reward_int[0].detach())
                done = terminated or truncated
                
                if not done:
                    next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
                else:
                    next_state = None
                if truncated:
                    self.agent_performance.append(0)
                
                #print("Extrinsic reward:", reward)
                #print("Intrinsic reward:", reward_int)
                self.memory.push(state, action, next_state, reward, reward_int)
                #self.intrinsic_rewards.append(reward_int)

                state = next_state
                
                loss_value = self.optimize_model()
                
                target_net_state_dict = self.target_net.state_dict()
                policy_net_state_dict = self.policy_net.state_dict()
                for key in policy_net_state_dict:
                    target_net_state_dict[key] = policy_net_state_dict[key]*self.TAU + target_net_state_dict[key]*(1-self.TAU)
                self.target_net.load_state_dict(target_net_state_dict)

                if done:
                    self.episode_durations.append(t + 1)
                    if terminated:
                        self.agent_performance.append(1)
                    else:
                        self.agent_performance.append(0)
                    print(f"Episode {episode}: episode duration {self.episode_durations[-1]}")
                    break
                    
                running_loss.append(loss_value)
                
            filtered_running_loss = [loss for loss in running_loss if loss is not None]
            if filtered_running_loss:
                self.loss_per_episode.append(np.mean(filtered_running_loss))

            self.cumulative_reward_per_episode.append(cumulative_reward_t)
            self.cumulative_environment_reward_per_episode.append(environment_reward_t)
            self.cumulative_intrinsic_reward_per_episode.append(intrinsic_reward_t.detach())

        return torch.save(self.policy_net.state_dict(), 'rnd_dqn_policynet.pth')
    
    def evaluate(self, modelfile, seedfile, num_episodes):
        self.policy_net.load_state_dict(torch.load(modelfile))
        with open(seedfile, 'r') as f:
            seeds = json.load(f)
        for i_episode in tqdm(range(num_episodes), desc="Episodes"):
            env.reset()
            state = seeds[i_episode]
            state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            for t in count():
                with torch.no_grad():
                    action = self.policy_net(state).max(1)[1].view(1, 1)
                observation, reward, terminated, truncated, _ = env.step(action.item())
                done = terminated or truncated
                if terminated:
                    next_state = None
                else:
                    next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
                state = next_state
                if done:
                    self.testing_durations.append(t + 1)
                    break

# %%
# set the run id
run_id = 1

def train_agent_with_hyperparameters(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TAU, LR, run_id, num_episodes=3000):
    n_actions = env.action_space.n
    n_observations = env.observation_space.shape[0]
    agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TAU, LR, n_actions, n_observations)
    agent.update(num_episodes, M=10)
    hyperparameters = f"BATCH_SIZE={BATCH_SIZE}_GAMMA={GAMMA}_EPS_START={EPS_START}_EPS_END={EPS_END}_EPS_DECAY={EPS_DECAY}_TAU={TAU}_LR={LR}"
    
    # Save the list to a file
    with open('RND_episode_durations.json', 'w') as f:
        json.dump(agent.episode_durations, f)
    with open('RND_cumulative_environment_reward_per_episode.json', 'w') as f:
        json.dump(agent.cumulative_environment_reward_per_episode, f)

    plot_durations(agent.episode_durations, run_id)
    plot_curve(agent.loss_per_episode, 'Loss Curve', 'Training Step', 'Loss', run_id)
    plot_cumul_reward(torch.tensor(agent.cumulative_reward_per_episode)/torch.tensor(agent.episode_durations), 'Episode', 'Cumulative Reward', run_id=20)
    plot_comp_cumul_reward(torch.tensor(agent.cumulative_reward_per_episode)/torch.tensor(agent.episode_durations), agent.cumulative_environment_reward_per_episode, agent.cumulative_intrinsic_reward_per_episode, run_id=20)
    cumulative_successes = cumulative_sum(agent.agent_performance)
    plot_curve(cumulative_successes, 'Cumulative Number of Successes', 'Episodes', 'Successes', run_id)
    return agent.episode_durations, agent.cumulative_reward_per_episode, agent.cumulative_environment_reward_per_episode, agent.cumulative_intrinsic_reward_per_episode, agent.agent_performance

def evaluate_agent(modelfile, seedfile, BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TAU, LR, run_id, num_episodes=1000):
    n_actions = env.action_space.n
    n_observations = env.observation_space.shape[0]
    agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TAU, LR, n_actions, n_observations)
    agent.evaluate(modelfile, seedfile, num_episodes)
    hyperparameters = f"BATCH_SIZE={BATCH_SIZE}_GAMMA={GAMMA}_EPS_START={EPS_START}_EPS_END={EPS_END}_EPS_DECAY={EPS_DECAY}_TAU={TAU}_LR={LR}"
    
    with open('RND_dqn_testing_durations.json', 'w') as f:
        json.dump(agent.testing_durations, f)

    plot_evaluation(agent.testing_durations, run_id)

episode_durations,cum_r, cum_env_r, cum_int_r, agent_performance = train_agent_with_hyperparameters(64, 0.99, 0.9, 0.1, 100000, 0.0005, 1e-4)
# Out:
# /var/folders/mg/44g5ch495hdc8x4_5mq3dsdm0000gn/T/ipykernel_23837/4001474754.py:130: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
# Episode 0: episode duration 200
# Episode 1: episode duration 200
# Episode 2: episode duration 200
# Episode 3: episode duration 200
# Episode 4: episode duration 200
# Episode 5: episode duration 200
# Episode 6: episode duration 200
# Episode 7: episode duration 200
# Episode 8: episode duration 200
# Episode 9: episode duration 200
# Episode 10: episode duration 200
# Episode 11: episode duration 200
# Episode 12: episode duration 200
# Episode 13: episode duration 200
# Episode 14: episode duration 200
# Episode 15: episode duration 200
# Episode 16: episode duration 200
# Episode 17: episode duration 200
# Episode 18: episode duration 200
# Episode 19: episode duration 200
# Episode 20: episode duration 200
# Episode 21: episode duration 200
# Episode 22: episode duration 200
# Episode 23: episode duration 200
# Episode 24: episode duration 200
# Episode 25: episode duration 200
# Episode 26: episode duration 200
# Episode 27: episode duration 200
# Episode 28: episode duration 200
# Episode 29: episode duration 200
# Episode 30: episode duration 200
# Episode 31: episode duration 200
# Episode 32: episode duration 200
# Episode 33: episode duration 200
# Episode 34: episode duration 200
# Episode 35: episode duration 200
# Episode 36: episode duration 200
# Episode 37: episode duration 200
# Episode 38: episode duration 200
# Episode 39: episode duration 200
# Episode 40: episode duration 200
# Episode 41: episode duration 200
# Episode 42: episode duration 200
# Episode 43: episode duration 200
# Episode 44: episode duration 200
# Episode 45: episode duration 200
# Episode 46: episode duration 200
# Episode 47: episode duration 200
# Episode 48: episode duration 200
# Episode 49: episode duration 200
# Episode 50: episode duration 200
# Episode 51: episode duration 200
# Episode 52: episode duration 200
# Episode 53: episode duration 200
# Episode 54: episode duration 200
# Episode 55: episode duration 200
# Episode 56: episode duration 200
# Episode 57: episode duration 200
# Episode 58: episode duration 200
# Episode 59: episode duration 200
# Episode 60: episode duration 200
# Episode 61: episode duration 200
# Episode 62: episode duration 200
# Episode 63: episode duration 200
# Episode 64: episode duration 200
# Episode 65: episode duration 200
# Episode 66: episode duration 200
# Episode 67: episode duration 200
# Episode 68: episode duration 200
# Episode 69: episode duration 200
# Episode 70: episode duration 200
# Episode 71: episode duration 200
# Episode 72: episode duration 200
# Episode 73: episode duration 200
# Episode 74: episode duration 200
# Episode 75: episode duration 200
# Episode 76: episode duration 200
# Episode 77: episode duration 200
# Episode 78: episode duration 200
# Episode 79: episode duration 200
# Episode 80: episode duration 200
# Episode 81: episode duration 200
# Episode 82: episode duration 200
# Episode 83: episode duration 200
# Episode 84: episode duration 200
# Episode 85: episode duration 200
# Episode 86: episode duration 200
# Episode 87: episode duration 200
# Episode 88: episode duration 200
# Episode 89: episode duration 200
# Episode 90: episode duration 200
# Episode 91: episode duration 200
# Episode 92: episode duration 200
# Episode 93: episode duration 200
# Episode 94: episode duration 200
# Episode 95: episode duration 200
# Episode 96: episode duration 200
# Episode 97: episode duration 200
# Episode 98: episode duration 200
# Episode 99: episode duration 200
# Episode 100: episode duration 200
# Episode 101: episode duration 200
# Episode 102: episode duration 200
# Episode 103: episode duration 200
# Episode 104: episode duration 200
# Episode 105: episode duration 200
# Episode 106: episode duration 200
# Episode 107: episode duration 200
# Episode 108: episode duration 200
# Episode 109: episode duration 200
# Episode 110: episode duration 200
# Episode 111: episode duration 200
# Episode 112: episode duration 200
# Episode 113: episode duration 200
# Episode 114: episode duration 200
# Episode 115: episode duration 200
# Episode 116: episode duration 200
# Episode 117: episode duration 200
# Episode 118: episode duration 200
# Episode 119: episode duration 200
# Episode 120: episode duration 200
# Episode 121: episode duration 200
# Episode 122: episode duration 200
# Episode 123: episode duration 200
# Episode 124: episode duration 200
# Episode 125: episode duration 200
# Episode 126: episode duration 200
# Episode 127: episode duration 200
# Episode 128: episode duration 200
# Episode 129: episode duration 200
# Episode 130: episode duration 200
# Episode 131: episode duration 200
# Episode 132: episode duration 200
# Episode 133: episode duration 200
# Episode 134: episode duration 200
# Episode 135: episode duration 200
# Episode 136: episode duration 200
# Episode 137: episode duration 200
# Episode 138: episode duration 200
# Episode 139: episode duration 200
# Episode 140: episode duration 200
# Episode 141: episode duration 200
# Episode 142: episode duration 200
# Episode 143: episode duration 200
# Episode 144: episode duration 200
# Episode 145: episode duration 200
# Episode 146: episode duration 200
# Episode 147: episode duration 200
# Episode 148: episode duration 200
# Episode 149: episode duration 200
# Episode 150: episode duration 200
# Episode 151: episode duration 200
# Episode 152: episode duration 200
# Episode 153: episode duration 200
# Episode 154: episode duration 200
# Episode 155: episode duration 200
# Episode 156: episode duration 200
# Episode 157: episode duration 200
# Episode 158: episode duration 200
# Episode 159: episode duration 200
# Episode 160: episode duration 200
# Episode 161: episode duration 200
# Episode 162: episode duration 200
# Episode 163: episode duration 200
# Episode 164: episode duration 200
# Episode 165: episode duration 200
# Episode 166: episode duration 200
# Episode 167: episode duration 200
# Episode 168: episode duration 200
# Episode 169: episode duration 200
# Episode 170: episode duration 200
# Episode 171: episode duration 200
# Episode 172: episode duration 200
# Episode 173: episode duration 200
# Episode 174: episode duration 200
# Episode 175: episode duration 200
# Episode 176: episode duration 200
# Episode 177: episode duration 200
# Episode 178: episode duration 200
# Episode 179: episode duration 200
# Episode 180: episode duration 200
# Episode 181: episode duration 200
# Episode 182: episode duration 200
# Episode 183: episode duration 200
# Episode 184: episode duration 200
# Episode 185: episode duration 200
# Episode 186: episode duration 200
# Episode 187: episode duration 200
# Episode 188: episode duration 200
# Episode 189: episode duration 200
# Episode 190: episode duration 200
# Episode 191: episode duration 200
# Episode 192: episode duration 200
# Episode 193: episode duration 200
# Episode 194: episode duration 200
# Episode 195: episode duration 200
# Episode 196: episode duration 200
# Episode 197: episode duration 200
# Episode 198: episode duration 200
# Episode 199: episode duration 200
# Episode 200: episode duration 200
# Episode 201: episode duration 200
# Episode 202: episode duration 200
# Episode 203: episode duration 200
# Episode 204: episode duration 200
# Episode 205: episode duration 200
# Episode 206: episode duration 200
# Episode 207: episode duration 200
# Episode 208: episode duration 200
# Episode 209: episode duration 200
# Episode 210: episode duration 200
# Episode 211: episode duration 200
# Episode 212: episode duration 200
# Episode 213: episode duration 200
# Episode 214: episode duration 200
# Episode 215: episode duration 200
# Episode 216: episode duration 200
# Episode 217: episode duration 200
# Episode 218: episode duration 200
# Episode 219: episode duration 200
# Episode 220: episode duration 200
# Episode 221: episode duration 200
# Episode 222: episode duration 200
# Episode 223: episode duration 200
# Episode 224: episode duration 200
# Episode 225: episode duration 200
# Episode 226: episode duration 200
# Episode 227: episode duration 200
# Episode 228: episode duration 200
# Episode 229: episode duration 200
# Episode 230: episode duration 200
# Episode 231: episode duration 200
# Episode 232: episode duration 200
# Episode 233: episode duration 200
# Episode 234: episode duration 200
# Episode 235: episode duration 200
# Episode 236: episode duration 200
# Episode 237: episode duration 200
# Episode 238: episode duration 200
# Episode 239: episode duration 200
# Episode 240: episode duration 200
# Episode 241: episode duration 200
# Episode 242: episode duration 200
# Episode 243: episode duration 200
# Episode 244: episode duration 200
# Episode 245: episode duration 200
# Episode 246: episode duration 200
# Episode 247: episode duration 200
# Episode 248: episode duration 200
# Episode 249: episode duration 200
# Episode 250: episode duration 200
# Episode 251: episode duration 200
# Episode 252: episode duration 200
# Episode 253: episode duration 200
# Episode 254: episode duration 200
# Episode 255: episode duration 200
# Episode 256: episode duration 200
# Episode 257: episode duration 200
# Episode 258: episode duration 200
# Episode 259: episode duration 200
# Episode 260: episode duration 200
# Episode 261: episode duration 200
# Episode 262: episode duration 200
# Episode 263: episode duration 200
# Episode 264: episode duration 200
# Episode 265: episode duration 200
# Episode 266: episode duration 200
# Episode 267: episode duration 200
# Episode 268: episode duration 200
# Episode 269: episode duration 200
# Episode 270: episode duration 200
# Episode 271: episode duration 200
# Episode 272: episode duration 200
# Episode 273: episode duration 200
# Episode 274: episode duration 200
# Episode 275: episode duration 200
# Episode 276: episode duration 200
# Episode 277: episode duration 200
# Episode 278: episode duration 200
# Episode 279: episode duration 200
# Episode 280: episode duration 200
# Episode 281: episode duration 200
# Episode 282: episode duration 200
# Episode 283: episode duration 200
# Episode 284: episode duration 200
# Episode 285: episode duration 200
# Episode 286: episode duration 200
# Episode 287: episode duration 200
# Episode 288: episode duration 200
# Episode 289: episode duration 200
# Episode 290: episode duration 200
# Episode 291: episode duration 200
# Episode 292: episode duration 200
# Episode 293: episode duration 200
# Episode 294: episode duration 200
# Episode 295: episode duration 200
# Episode 296: episode duration 200
# Episode 297: episode duration 200
# Episode 298: episode duration 200
# Episode 299: episode duration 200
# Episode 300: episode duration 200
# Episode 301: episode duration 200
# Episode 302: episode duration 200
# Episode 303: episode duration 200
# Episode 304: episode duration 200
# Episode 305: episode duration 200
# Episode 306: episode duration 200
# Episode 307: episode duration 200
# Episode 308: episode duration 200
# Episode 309: episode duration 200
# Episode 310: episode duration 200
# Episode 311: episode duration 200
# Episode 312: episode duration 200
# Episode 313: episode duration 200
# Episode 314: episode duration 200
# Episode 315: episode duration 200
# Episode 316: episode duration 200
# Episode 317: episode duration 200
# Episode 318: episode duration 200
# Episode 319: episode duration 200
# Episode 320: episode duration 200
# Episode 321: episode duration 200
# Episode 322: episode duration 200
# Episode 323: episode duration 200
# Episode 324: episode duration 200
# Episode 325: episode duration 200
# Episode 326: episode duration 200
# Episode 327: episode duration 200
# Episode 328: episode duration 200
# Episode 329: episode duration 200
# Episode 330: episode duration 200
# Episode 331: episode duration 200
# Episode 332: episode duration 200
# Episode 333: episode duration 200
# Episode 334: episode duration 200
# Episode 335: episode duration 200
# Episode 336: episode duration 200
# Episode 337: episode duration 200
# Episode 338: episode duration 200
# Episode 339: episode duration 200
# Episode 340: episode duration 200
# Episode 341: episode duration 200
# Episode 342: episode duration 200
# Episode 343: episode duration 200
# Episode 344: episode duration 200
# Episode 345: episode duration 200
# Episode 346: episode duration 200
# Episode 347: episode duration 200
# Episode 348: episode duration 200
# Episode 349: episode duration 200
# Episode 350: episode duration 200
# Episode 351: episode duration 200
# Episode 352: episode duration 200
# Episode 353: episode duration 200
# Episode 354: episode duration 200
# Episode 355: episode duration 200
# Episode 356: episode duration 200
# Episode 357: episode duration 200
# Episode 358: episode duration 200
# Episode 359: episode duration 200
# Episode 360: episode duration 200
# Episode 361: episode duration 200
# Episode 362: episode duration 200
# Episode 363: episode duration 200
# Episode 364: episode duration 200
# Episode 365: episode duration 200
# Episode 366: episode duration 200
# Episode 367: episode duration 200
# Episode 368: episode duration 200
# Episode 369: episode duration 200
# Episode 370: episode duration 200
# Episode 371: episode duration 200
# Episode 372: episode duration 200
# Episode 373: episode duration 200
# Episode 374: episode duration 200
# Episode 375: episode duration 200
# Episode 376: episode duration 200
# Episode 377: episode duration 200
# Episode 378: episode duration 200
# Episode 379: episode duration 200
# Episode 380: episode duration 200
# Episode 381: episode duration 200
# Episode 382: episode duration 200
# Episode 383: episode duration 200
# Episode 384: episode duration 200
# Episode 385: episode duration 200
# Episode 386: episode duration 200
# Episode 387: episode duration 200
# Episode 388: episode duration 200
# Episode 389: episode duration 200
# Episode 390: episode duration 200
# Episode 391: episode duration 200
# Episode 392: episode duration 200
# Episode 393: episode duration 200
# Episode 394: episode duration 200
# Episode 395: episode duration 200
# Episode 396: episode duration 200
# Episode 397: episode duration 200
# Episode 398: episode duration 200
# Episode 399: episode duration 200
# Episode 400: episode duration 200
# Episode 401: episode duration 200
# Episode 402: episode duration 200
# Episode 403: episode duration 200
# Episode 404: episode duration 200
# Episode 405: episode duration 200
# Episode 406: episode duration 200
# Episode 407: episode duration 200
# Episode 408: episode duration 200
# Episode 409: episode duration 200
# Episode 410: episode duration 200
# Episode 411: episode duration 200
# Episode 412: episode duration 200
# Episode 413: episode duration 200
# Episode 414: episode duration 200
# Episode 415: episode duration 200
# Episode 416: episode duration 200
# Episode 417: episode duration 200
# Episode 418: episode duration 200
# Episode 419: episode duration 200
# Episode 420: episode duration 200
# Episode 421: episode duration 200
# Episode 422: episode duration 200
# Episode 423: episode duration 200
# Episode 424: episode duration 200
# Episode 425: episode duration 200
# Episode 426: episode duration 200
# Episode 427: episode duration 200
# Episode 428: episode duration 200
# Episode 429: episode duration 200
# Episode 430: episode duration 200
# Episode 431: episode duration 200
# Episode 432: episode duration 200
# Episode 433: episode duration 200
# Episode 434: episode duration 200
# Episode 435: episode duration 200
# Episode 436: episode duration 200
# Episode 437: episode duration 200
# Episode 438: episode duration 200
# Episode 439: episode duration 200
# Episode 440: episode duration 200
# Episode 441: episode duration 200
# Episode 442: episode duration 200
# Episode 443: episode duration 200
# Episode 444: episode duration 200
# Episode 445: episode duration 200
# Episode 446: episode duration 200
# Episode 447: episode duration 200
# Episode 448: episode duration 200
# Episode 449: episode duration 200
# Episode 450: episode duration 200
# Episode 451: episode duration 200
# Episode 452: episode duration 200
# Episode 453: episode duration 200
# Episode 454: episode duration 200
# Episode 455: episode duration 200
# Episode 456: episode duration 200
# Episode 457: episode duration 200
# Episode 458: episode duration 200
# Episode 459: episode duration 200
# Episode 460: episode duration 200
# Episode 461: episode duration 200
# Episode 462: episode duration 200
# Episode 463: episode duration 200
# Episode 464: episode duration 200
# Episode 465: episode duration 200
# Episode 466: episode duration 200
# Episode 467: episode duration 200
# Episode 468: episode duration 200
# Episode 469: episode duration 200
# Episode 470: episode duration 200
# Episode 471: episode duration 200
# Episode 472: episode duration 200
# Episode 473: episode duration 200
# Episode 474: episode duration 200
# Episode 475: episode duration 200
# Episode 476: episode duration 200
# Episode 477: episode duration 200
# Episode 478: episode duration 200
# Episode 479: episode duration 200
# Episode 480: episode duration 200
# Episode 481: episode duration 200
# Episode 482: episode duration 200
# Episode 483: episode duration 200
# Episode 484: episode duration 200
# Episode 485: episode duration 200
# Episode 486: episode duration 200
# Episode 487: episode duration 200
# Episode 488: episode duration 200
# Episode 489: episode duration 200
# Episode 490: episode duration 200
# Episode 491: episode duration 200
# Episode 492: episode duration 200
# Episode 493: episode duration 200
# Episode 494: episode duration 200
# Episode 495: episode duration 200
# Episode 496: episode duration 200
# Episode 497: episode duration 200
# Episode 498: episode duration 200
# Episode 499: episode duration 200
# Episode 500: episode duration 200
# Episode 501: episode duration 200
# Episode 502: episode duration 200
# Episode 503: episode duration 200
# Episode 504: episode duration 200
# Episode 505: episode duration 200
# Episode 506: episode duration 200
# Episode 507: episode duration 200
# Episode 508: episode duration 200
# Episode 509: episode duration 200
# Episode 510: episode duration 200
# Episode 511: episode duration 200
# Episode 512: episode duration 200
# Episode 513: episode duration 200
# Episode 514: episode duration 200
# Episode 515: episode duration 200
# Episode 516: episode duration 200
# Episode 517: episode duration 200
# Episode 518: episode duration 200
# Episode 519: episode duration 200
# Episode 520: episode duration 200
# Episode 521: episode duration 200
# Episode 522: episode duration 200
# Episode 523: episode duration 200
# Episode 524: episode duration 200
# Episode 525: episode duration 200
# Episode 526: episode duration 200
# Episode 527: episode duration 200
# Episode 528: episode duration 200
# Episode 529: episode duration 200
# Episode 530: episode duration 200
# Episode 531: episode duration 200
# Episode 532: episode duration 200
# Episode 533: episode duration 200
# Episode 534: episode duration 200
# Episode 535: episode duration 200
# Episode 536: episode duration 200
# Episode 537: episode duration 200
# Episode 538: episode duration 200
# Episode 539: episode duration 200
# Episode 540: episode duration 200
# Episode 541: episode duration 200
# Episode 542: episode duration 200
# Episode 543: episode duration 200
# Episode 544: episode duration 200
# Episode 545: episode duration 200
# Episode 546: episode duration 200
# Episode 547: episode duration 200
# Episode 548: episode duration 200
# Episode 549: episode duration 200
# Episode 550: episode duration 200
# Episode 551: episode duration 200
# Episode 552: episode duration 200
# Episode 553: episode duration 200
# Episode 554: episode duration 200
# Episode 555: episode duration 200
# Episode 556: episode duration 200
# Episode 557: episode duration 200
# Episode 558: episode duration 200
# Episode 559: episode duration 200
# Episode 560: episode duration 200
# Episode 561: episode duration 200
# Episode 562: episode duration 200
# Episode 563: episode duration 200
# Episode 564: episode duration 200
# Episode 565: episode duration 200
# Episode 566: episode duration 200
# Episode 567: episode duration 200
# Episode 568: episode duration 200
# Episode 569: episode duration 200
# Episode 570: episode duration 200
# Episode 571: episode duration 200
# Episode 572: episode duration 200
# Episode 573: episode duration 200
# Episode 574: episode duration 200
# Episode 575: episode duration 200
# Episode 576: episode duration 200
# Episode 577: episode duration 200
# Episode 578: episode duration 200
# Episode 579: episode duration 200
# Episode 580: episode duration 200
# Episode 581: episode duration 200
# Episode 582: episode duration 200
# Episode 583: episode duration 200
# Episode 584: episode duration 200
# Episode 585: episode duration 200
# Episode 586: episode duration 200
# Episode 587: episode duration 200
# Episode 588: episode duration 200
# Episode 589: episode duration 200
# Episode 590: episode duration 200
# Episode 591: episode duration 200
# Episode 592: episode duration 200
# Episode 593: episode duration 200
# Episode 594: episode duration 200
# Episode 595: episode duration 200
# Episode 596: episode duration 200
# Episode 597: episode duration 200
# Episode 598: episode duration 200
# Episode 599: episode duration 200
# Episode 600: episode duration 200
# Episode 601: episode duration 200
# Episode 602: episode duration 200
# Episode 603: episode duration 200
# Episode 604: episode duration 200
# Episode 605: episode duration 200
# Episode 606: episode duration 200
# Episode 607: episode duration 200
# Episode 608: episode duration 200
# Episode 609: episode duration 200
# Episode 610: episode duration 200
# Episode 611: episode duration 200
# Episode 612: episode duration 200
# Episode 613: episode duration 200
# Episode 614: episode duration 200
# Episode 615: episode duration 200
# Episode 616: episode duration 200
# Episode 617: episode duration 200
# Episode 618: episode duration 200
# Episode 619: episode duration 200
# Episode 620: episode duration 200
# Episode 621: episode duration 200
# Episode 622: episode duration 200
# Episode 623: episode duration 200
# Episode 624: episode duration 200
# Episode 625: episode duration 200
# Episode 626: episode duration 200
# Episode 627: episode duration 200
# Episode 628: episode duration 200
# Episode 629: episode duration 200
# Episode 630: episode duration 200
# Episode 631: episode duration 200
# Episode 632: episode duration 200
# Episode 633: episode duration 200
# Episode 634: episode duration 200
# Episode 635: episode duration 200
# Episode 636: episode duration 200
# Episode 637: episode duration 200
# Episode 638: episode duration 200
# Episode 639: episode duration 200
# Episode 640: episode duration 200
# Episode 641: episode duration 200
# Episode 642: episode duration 200
# Episode 643: episode duration 200
# Episode 644: episode duration 200
# Episode 645: episode duration 200
# Episode 646: episode duration 200
# Episode 647: episode duration 200
# Episode 648: episode duration 200
# Episode 649: episode duration 200
# Episode 650: episode duration 200
# Episode 651: episode duration 200
# Episode 652: episode duration 200
# Episode 653: episode duration 200
# Episode 654: episode duration 200
# Episode 655: episode duration 200
# Episode 656: episode duration 200
# Episode 657: episode duration 200
# Episode 658: episode duration 200
# Episode 659: episode duration 200
# Episode 660: episode duration 200
# Episode 661: episode duration 200
# Episode 662: episode duration 200
# Episode 663: episode duration 200
# Episode 664: episode duration 200
# Episode 665: episode duration 200
# Episode 666: episode duration 200
# Episode 667: episode duration 200
# Episode 668: episode duration 200
# Episode 669: episode duration 200
# Episode 670: episode duration 200
# Episode 671: episode duration 200
# Episode 672: episode duration 200
# Episode 673: episode duration 200
# Episode 674: episode duration 200
# Episode 675: episode duration 200
# Episode 676: episode duration 200
# Episode 677: episode duration 200
# Episode 678: episode duration 200
# Episode 679: episode duration 200
# Episode 680: episode duration 200
# Episode 681: episode duration 200
# Episode 682: episode duration 200
# Episode 683: episode duration 200
# Episode 684: episode duration 200
# Episode 685: episode duration 200
# Episode 686: episode duration 200
# Episode 687: episode duration 200
# Episode 688: episode duration 200
# Episode 689: episode duration 200
# Episode 690: episode duration 200
# Episode 691: episode duration 200
# Episode 692: episode duration 200
# Episode 693: episode duration 200
# Episode 694: episode duration 200
# Episode 695: episode duration 200
# Episode 696: episode duration 200
# Episode 697: episode duration 200
# Episode 698: episode duration 200
# Episode 699: episode duration 200
# Episode 700: episode duration 200
# Episode 701: episode duration 200
# Episode 702: episode duration 200
# Episode 703: episode duration 200
# Episode 704: episode duration 200
# Episode 705: episode duration 200
# Episode 706: episode duration 200
# Episode 707: episode duration 200
# Episode 708: episode duration 200
# Episode 709: episode duration 200
# Episode 710: episode duration 200
# Episode 711: episode duration 200
# Episode 712: episode duration 200
# Episode 713: episode duration 200
# Episode 714: episode duration 200
# Episode 715: episode duration 200
# Episode 716: episode duration 200
# Episode 717: episode duration 200
# Episode 718: episode duration 200
# Episode 719: episode duration 200
# Episode 720: episode duration 200
# Episode 721: episode duration 200
# Episode 722: episode duration 200
# Episode 723: episode duration 200
# Episode 724: episode duration 200
# Episode 725: episode duration 200
# Episode 726: episode duration 200
# Episode 727: episode duration 200
# Episode 728: episode duration 200
# Episode 729: episode duration 200
# Episode 730: episode duration 200
# Episode 731: episode duration 200
# Episode 732: episode duration 200
# Episode 733: episode duration 200
# Episode 734: episode duration 200
# Episode 735: episode duration 200
# Episode 736: episode duration 200
# Episode 737: episode duration 200
# Episode 738: episode duration 200
# Episode 739: episode duration 200
# Episode 740: episode duration 200
# Episode 741: episode duration 200
# Episode 742: episode duration 200
# Episode 743: episode duration 200
# Episode 744: episode duration 200
# Episode 745: episode duration 200
# Episode 746: episode duration 200
# Episode 747: episode duration 200
# Episode 748: episode duration 200
# Episode 749: episode duration 200
# Episode 750: episode duration 200
# Episode 751: episode duration 200
# Episode 752: episode duration 200
# Episode 753: episode duration 200
# Episode 754: episode duration 200
# Episode 755: episode duration 200
# Episode 756: episode duration 200
# Episode 757: episode duration 200
# Episode 758: episode duration 200
# Episode 759: episode duration 200
# Episode 760: episode duration 200
# Episode 761: episode duration 200
# Episode 762: episode duration 200
# Episode 763: episode duration 200
# Episode 764: episode duration 200
# Episode 765: episode duration 200
# Episode 766: episode duration 200
# Episode 767: episode duration 200
# Episode 768: episode duration 200
# Episode 769: episode duration 200
# Episode 770: episode duration 200
# Episode 771: episode duration 200
# Episode 772: episode duration 200
# Episode 773: episode duration 200
# Episode 774: episode duration 200
# Episode 775: episode duration 200
# Episode 776: episode duration 200
# Episode 777: episode duration 200
# Episode 778: episode duration 200
# Episode 779: episode duration 200
# Episode 780: episode duration 200
# Episode 781: episode duration 200
# Episode 782: episode duration 200
# Episode 783: episode duration 200
# Episode 784: episode duration 200
# Episode 785: episode duration 200
# Episode 786: episode duration 200
# Episode 787: episode duration 200
# Episode 788: episode duration 200
# Episode 789: episode duration 200
# Episode 790: episode duration 200
# Episode 791: episode duration 200
# Episode 792: episode duration 200
# Episode 793: episode duration 200
# Episode 794: episode duration 200
# Episode 795: episode duration 200
# Episode 796: episode duration 200
# Episode 797: episode duration 200
# Episode 798: episode duration 200
# Episode 799: episode duration 200
# Episode 800: episode duration 200
# Episode 801: episode duration 200
# Episode 802: episode duration 200
# Episode 803: episode duration 200
# Episode 804: episode duration 200
# Episode 805: episode duration 200
# Episode 806: episode duration 200
# Episode 807: episode duration 200
# Episode 808: episode duration 200
# Episode 809: episode duration 200
# Episode 810: episode duration 200
# Episode 811: episode duration 200
# Episode 812: episode duration 200
# Episode 813: episode duration 200
# Episode 814: episode duration 200
# Episode 815: episode duration 200
# Episode 816: episode duration 200
# Episode 817: episode duration 200
# Episode 818: episode duration 200
# Episode 819: episode duration 200
# Episode 820: episode duration 200
# Episode 821: episode duration 200
# Episode 822: episode duration 200
# Episode 823: episode duration 200
# Episode 824: episode duration 200
# Episode 825: episode duration 200
# Episode 826: episode duration 200
# Episode 827: episode duration 200
# Episode 828: episode duration 200
# Episode 829: episode duration 200
# Episode 830: episode duration 200
# Episode 831: episode duration 200
# Episode 832: episode duration 200
# Episode 833: episode duration 200
# Episode 834: episode duration 200
# Episode 835: episode duration 200
# Episode 836: episode duration 200
# Episode 837: episode duration 200
# Episode 838: episode duration 200
# Episode 839: episode duration 200
# Episode 840: episode duration 200
# Episode 841: episode duration 200
# Episode 842: episode duration 200
# Episode 843: episode duration 200
# Episode 844: episode duration 200
# Episode 845: episode duration 200
# Episode 846: episode duration 200
# Episode 847: episode duration 200
# Episode 848: episode duration 200
# Episode 849: episode duration 200
# Episode 850: episode duration 200
# Episode 851: episode duration 200
# Episode 852: episode duration 200
# Episode 853: episode duration 200
# Episode 854: episode duration 200
# Episode 855: episode duration 200
# Episode 856: episode duration 200
# Episode 857: episode duration 200
# Episode 858: episode duration 200
# Episode 859: episode duration 200
# Episode 860: episode duration 200
# Episode 861: episode duration 200
# Episode 862: episode duration 200
# Episode 863: episode duration 200
# Episode 864: episode duration 200
# Episode 865: episode duration 200
# Episode 866: episode duration 200
# Episode 867: episode duration 200
# Episode 868: episode duration 200
# Episode 869: episode duration 200
# Episode 870: episode duration 200
# Episode 871: episode duration 200
# Episode 872: episode duration 200
# Episode 873: episode duration 200
# Episode 874: episode duration 200
# Episode 875: episode duration 200
# Episode 876: episode duration 200
# Episode 877: episode duration 200
# Episode 878: episode duration 200
# Episode 879: episode duration 200
# Episode 880: episode duration 200
# Episode 881: episode duration 200
# Episode 882: episode duration 200
# Episode 883: episode duration 200
# Episode 884: episode duration 200
# Episode 885: episode duration 200
# Episode 886: episode duration 200
# Episode 887: episode duration 200
# Episode 888: episode duration 200
# Episode 889: episode duration 200
# Episode 890: episode duration 200
# Episode 891: episode duration 200
# Episode 892: episode duration 200
# Episode 893: episode duration 200
# Episode 894: episode duration 200
# Episode 895: episode duration 200
# Episode 896: episode duration 200
# Episode 897: episode duration 200
# Episode 898: episode duration 200
# Episode 899: episode duration 200
# Episode 900: episode duration 200
# Episode 901: episode duration 200
# Episode 902: episode duration 200
# Episode 903: episode duration 200
# Episode 904: episode duration 200
# Episode 905: episode duration 200
# Episode 906: episode duration 200
# Episode 907: episode duration 200
# Episode 908: episode duration 200
# Episode 909: episode duration 200
# Episode 910: episode duration 200
# Episode 911: episode duration 200
# Episode 912: episode duration 200
# Episode 913: episode duration 200
# Episode 914: episode duration 200
# Episode 915: episode duration 200
# Episode 916: episode duration 200
# Episode 917: episode duration 200
# Episode 918: episode duration 200
# Episode 919: episode duration 200
# Episode 920: episode duration 200
# Episode 921: episode duration 200
# Episode 922: episode duration 200
# Episode 923: episode duration 200
# Episode 924: episode duration 200
# Episode 925: episode duration 200
# Episode 926: episode duration 200
# Episode 927: episode duration 200
# Episode 928: episode duration 200
# Episode 929: episode duration 200
# Episode 930: episode duration 200
# Episode 931: episode duration 200
# Episode 932: episode duration 200
# Episode 933: episode duration 200
# Episode 934: episode duration 200
# Episode 935: episode duration 200
# Episode 936: episode duration 200
# Episode 937: episode duration 200
# Episode 938: episode duration 200
# Episode 939: episode duration 200
# Episode 940: episode duration 200
# Episode 941: episode duration 200
# Episode 942: episode duration 200
# Episode 943: episode duration 200
# Episode 944: episode duration 200
# Episode 945: episode duration 200
# Episode 946: episode duration 200
# Episode 947: episode duration 183
# Episode 948: episode duration 200
# Episode 949: episode duration 200
# Episode 950: episode duration 200
# Episode 951: episode duration 184
# Episode 952: episode duration 200
# Episode 953: episode duration 200
# Episode 954: episode duration 200
# Episode 955: episode duration 200
# Episode 956: episode duration 200
# Episode 957: episode duration 200
# Episode 958: episode duration 200
# Episode 959: episode duration 200
# Episode 960: episode duration 187
# Episode 961: episode duration 200
# Episode 962: episode duration 200
# Episode 963: episode duration 168
# Episode 964: episode duration 200
# Episode 965: episode duration 200
# Episode 966: episode duration 200
# Episode 967: episode duration 200
# Episode 968: episode duration 200
# Episode 969: episode duration 200
# Episode 970: episode duration 200
# Episode 971: episode duration 200
# Episode 972: episode duration 200
# Episode 973: episode duration 200
# Episode 974: episode duration 200
# Episode 975: episode duration 200
# Episode 976: episode duration 200
# Episode 977: episode duration 200
# Episode 978: episode duration 200
# Episode 979: episode duration 200
# Episode 980: episode duration 200
# Episode 981: episode duration 200
# Episode 982: episode duration 200
# Episode 983: episode duration 179
# Episode 984: episode duration 200
# Episode 985: episode duration 200
# Episode 986: episode duration 200
# Episode 987: episode duration 200
# Episode 988: episode duration 200
# Episode 989: episode duration 200
# Episode 990: episode duration 200
# Episode 991: episode duration 200
# Episode 992: episode duration 200
# Episode 993: episode duration 200
# Episode 994: episode duration 200
# Episode 995: episode duration 200
# Episode 996: episode duration 200
# Episode 997: episode duration 200
# Episode 998: episode duration 200
# Episode 999: episode duration 200
# Episode 1000: episode duration 200
# Episode 1001: episode duration 200
# Episode 1002: episode duration 200
# Episode 1003: episode duration 200
# Episode 1004: episode duration 200
# Episode 1005: episode duration 200
# Episode 1006: episode duration 200
# Episode 1007: episode duration 200
# Episode 1008: episode duration 200
# Episode 1009: episode duration 200
# Episode 1010: episode duration 200
# Episode 1011: episode duration 200
# Episode 1012: episode duration 200
# Episode 1013: episode duration 200
# Episode 1014: episode duration 200
# Episode 1015: episode duration 200
# Episode 1016: episode duration 200
# Episode 1017: episode duration 200
# Episode 1018: episode duration 200
# Episode 1019: episode duration 200
# Episode 1020: episode duration 200
# Episode 1021: episode duration 200
# Episode 1022: episode duration 200
# Episode 1023: episode duration 200
# Episode 1024: episode duration 200
# Episode 1025: episode duration 200
# Episode 1026: episode duration 200
# Episode 1027: episode duration 200
# Episode 1028: episode duration 200
# Episode 1029: episode duration 200
# Episode 1030: episode duration 200
# Episode 1031: episode duration 200
# Episode 1032: episode duration 200
# Episode 1033: episode duration 200
# Episode 1034: episode duration 200
# Episode 1035: episode duration 200
# Episode 1036: episode duration 200
# Episode 1037: episode duration 200
# Episode 1038: episode duration 200
# Episode 1039: episode duration 200
# Episode 1040: episode duration 200
# Episode 1041: episode duration 168
# Episode 1042: episode duration 200
# Episode 1043: episode duration 200
# Episode 1044: episode duration 200
# Episode 1045: episode duration 200
# Episode 1046: episode duration 200
# Episode 1047: episode duration 169
# Episode 1048: episode duration 200
# Episode 1049: episode duration 200
# Episode 1050: episode duration 200
# Episode 1051: episode duration 165
# Episode 1052: episode duration 200
# Episode 1053: episode duration 199
# Episode 1054: episode duration 200
# Episode 1055: episode duration 200
# Episode 1056: episode duration 200
# Episode 1057: episode duration 175
# Episode 1058: episode duration 200
# Episode 1059: episode duration 166
# Episode 1060: episode duration 200
# Episode 1061: episode duration 178
# Episode 1062: episode duration 200
# Episode 1063: episode duration 181
# Episode 1064: episode duration 200
# Episode 1065: episode duration 175
# Episode 1066: episode duration 166
# Episode 1067: episode duration 197
# Episode 1068: episode duration 200
# Episode 1069: episode duration 200
# Episode 1070: episode duration 200
# Episode 1071: episode duration 200
# Episode 1072: episode duration 165
# Episode 1073: episode duration 200
# Episode 1074: episode duration 157
# Episode 1075: episode duration 200
# Episode 1076: episode duration 200
# Episode 1077: episode duration 200
# Episode 1078: episode duration 200
# Episode 1079: episode duration 200
# Episode 1080: episode duration 200
# Episode 1081: episode duration 200
# Episode 1082: episode duration 200
# Episode 1083: episode duration 200
# Episode 1084: episode duration 164
# Episode 1085: episode duration 200
# Episode 1086: episode duration 200
# Episode 1087: episode duration 200
# Episode 1088: episode duration 160
# Episode 1089: episode duration 200
# Episode 1090: episode duration 200
# Episode 1091: episode duration 149
# Episode 1092: episode duration 182
# Episode 1093: episode duration 200
# Episode 1094: episode duration 200
# Episode 1095: episode duration 200
# Episode 1096: episode duration 155
# Episode 1097: episode duration 200
# Episode 1098: episode duration 200
# Episode 1099: episode duration 200
# Episode 1100: episode duration 200
# Episode 1101: episode duration 200
# Episode 1102: episode duration 200
# Episode 1103: episode duration 200
# Episode 1104: episode duration 200
# Episode 1105: episode duration 200
# Episode 1106: episode duration 200
# Episode 1107: episode duration 200
# Episode 1108: episode duration 200
# Episode 1109: episode duration 200
# Episode 1110: episode duration 156
# Episode 1111: episode duration 200
# Episode 1112: episode duration 200
# Episode 2810: episode duration 200
# Episode 2811: episode duration 200
# Episode 2812: episode duration 200
# Episode 2813: episode duration 200
# Episode 2814: episode duration 200
# Episode 2815: episode duration 144
# Episode 2816: episode duration 200
# Episode 2817: episode duration 200
# Episode 2818: episode duration 200
# Episode 2819: episode duration 147
# Episode 2820: episode duration 200
# Episode 2821: episode duration 200
# Episode 2822: episode duration 200
# Episode 2823: episode duration 200
# Episode 2824: episode duration 200
# Episode 2825: episode duration 200
# Episode 2826: episode duration 200
# Episode 2827: episode duration 141
# Episode 2828: episode duration 200
# Episode 2829: episode duration 200
# Episode 2830: episode duration 200
# Episode 2831: episode duration 200
# Episode 2832: episode duration 200
# Episode 2833: episode duration 200
# Episode 2834: episode duration 200
# Episode 2835: episode duration 200
# Episode 2836: episode duration 200
# Episode 2837: episode duration 200
# Episode 2838: episode duration 200
# Episode 2839: episode duration 200
# Episode 2840: episode duration 200
# Episode 2841: episode duration 200
# Episode 2842: episode duration 200
# Episode 2843: episode duration 200
# Episode 2844: episode duration 200
# Episode 2845: episode duration 200
# Episode 2846: episode duration 200
# Episode 2847: episode duration 200
# Episode 2848: episode duration 200
# Episode 2849: episode duration 200
# Episode 2850: episode duration 200
# Episode 2851: episode duration 200
# Episode 2852: episode duration 200
# Episode 2853: episode duration 200
# Episode 2854: episode duration 200
# Episode 2855: episode duration 200
# Episode 2856: episode duration 200
# Episode 2857: episode duration 200
# Episode 2858: episode duration 200
# Episode 2859: episode duration 200
# Episode 2860: episode duration 200
# Episode 2861: episode duration 200
# Episode 2862: episode duration 200
# Episode 2863: episode duration 200
# Episode 2864: episode duration 200
# Episode 2865: episode duration 200
# Episode 2866: episode duration 200
# Episode 2867: episode duration 145
# Episode 2868: episode duration 152
# Episode 2869: episode duration 148
# Episode 2870: episode duration 200
# Episode 2871: episode duration 141
# Episode 2872: episode duration 171
# Episode 2873: episode duration 200
# Episode 2874: episode duration 146
# Episode 2875: episode duration 200
# Episode 2876: episode duration 174
# Episode 2877: episode duration 200
# Episode 2878: episode duration 200
# Episode 2879: episode duration 200
# Episode 2880: episode duration 200
# Episode 2881: episode duration 176
# Episode 2882: episode duration 200
# Episode 2883: episode duration 200
# Episode 2884: episode duration 200
# Episode 2885: episode duration 200
# Episode 2886: episode duration 200
# Episode 2887: episode duration 181
# Episode 2888: episode duration 200
# Episode 2889: episode duration 200
# Episode 2890: episode duration 200
# Episode 2891: episode duration 200
# Episode 2892: episode duration 200
# Episode 2893: episode duration 200
# Episode 2894: episode duration 174
# Episode 2895: episode duration 200
# Episode 2896: episode duration 190
# Episode 2897: episode duration 185
# Episode 2898: episode duration 170
# Episode 2899: episode duration 184
# Episode 2900: episode duration 200
# Episode 2901: episode duration 195
# Episode 2902: episode duration 200
# Episode 2903: episode duration 200
# Episode 2904: episode duration 200
# Episode 2905: episode duration 173
# Episode 2906: episode duration 200
# Episode 2907: episode duration 200
# Episode 2908: episode duration 181
# Episode 2909: episode duration 200
# Episode 2910: episode duration 200
# Episode 2911: episode duration 174
# Episode 2912: episode duration 183
# Episode 2913: episode duration 200
# Episode 2914: episode duration 200
# Episode 2915: episode duration 177
# Episode 2916: episode duration 173
# Episode 2917: episode duration 200
# Episode 2918: episode duration 200
# Episode 2919: episode duration 200
# Episode 2920: episode duration 175
# Episode 2921: episode duration 172
# Episode 2922: episode duration 171
# Episode 2923: episode duration 200
# Episode 2924: episode duration 177
# Episode 2925: episode duration 200
# Episode 2926: episode duration 200
# Episode 2927: episode duration 169
# Episode 2928: episode duration 200
# Episode 2929: episode duration 178
# Episode 2930: episode duration 200
# Episode 2931: episode duration 200
# Episode 2932: episode duration 200
# Episode 2933: episode duration 171
# Episode 2934: episode duration 200
# Episode 2935: episode duration 200
# Episode 2936: episode duration 200
# Episode 2937: episode duration 178
# Episode 2938: episode duration 200
# Episode 2939: episode duration 200
# Episode 2940: episode duration 200
# Episode 2941: episode duration 200
# Episode 2942: episode duration 124
# Episode 2943: episode duration 200
# Episode 2944: episode duration 200
# Episode 2945: episode duration 200
# Episode 2946: episode duration 200
# Episode 2947: episode duration 200
# Episode 2948: episode duration 200
# Episode 2949: episode duration 200
# Episode 2950: episode duration 173
# Episode 2951: episode duration 200
# Episode 2952: episode duration 200
# Episode 2953: episode duration 174
# Episode 2954: episode duration 175
# Episode 2955: episode duration 172
# Episode 2956: episode duration 171
# Episode 2957: episode duration 200
# Episode 2958: episode duration 200
# Episode 2959: episode duration 200
# Episode 2960: episode duration 200
# Episode 2961: episode duration 200
# Episode 2962: episode duration 200
# Episode 2963: episode duration 170
# Episode 2964: episode duration 200
# Episode 2965: episode duration 200
# Episode 2966: episode duration 175
# Episode 2967: episode duration 183
# Episode 2968: episode duration 172
# Episode 2969: episode duration 172
# Episode 2970: episode duration 174
# Episode 2971: episode duration 173
# Episode 2972: episode duration 200
# Episode 2973: episode duration 177
# Episode 2974: episode duration 200
# Episode 2975: episode duration 200
# Episode 2976: episode duration 178
# Episode 2977: episode duration 168
# Episode 2978: episode duration 200
# Episode 2979: episode duration 176
# Episode 2980: episode duration 179
# Episode 2981: episode duration 186
# Episode 2982: episode duration 178
# Episode 2983: episode duration 176
# Episode 2984: episode duration 173
# Episode 2985: episode duration 191
# Episode 2986: episode duration 174
# Episode 2987: episode duration 112
# Episode 2988: episode duration 176
# Episode 2989: episode duration 200
# Episode 2990: episode duration 180
# Episode 2991: episode duration 178
# Episode 2992: episode duration 184
# Episode 2993: episode duration 200
# Episode 2994: episode duration 185
# Episode 2995: episode duration 190
# Episode 2996: episode duration 108
# Episode 2997: episode duration 180
# Episode 2998: episode duration 187
# Episode 2999: episode duration 200
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /var/folders/mg/44g5ch495hdc8x4_5mq3dsdm0000gn/T/ipykernel_23837/169083777.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_t = torch.tensor(data, dtype=torch.float)
# /var/folders/mg/44g5ch495hdc8x4_5mq3dsdm0000gn/T/ipykernel_23837/169083777.py:54: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_t = torch.tensor(data, dtype=torch.float)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
evaluate_agent('rnd_dqn_policynet.pth', 'seeds.json', 64, 0.99, 0.9, 0.1, 100000, 0.0001, 1e-4, 1000)
# Out:
# Episodes: 100%|██████████| 1000/1000 [00:03<00:00, 250.87it/s]
